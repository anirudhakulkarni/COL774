# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
X=pd.read_csv("data/q1/linearX.csv",header=None)
Y=pd.read_csv("data/q1/linearY.csv",header=None)
m=len(X)
X = np.array(X)
Y = np.array(Y)
mean=np.mean(X)
var=np.var(X)
X=(X-mean)/var
X1=X
plt.scatter(X,Y)

# %%
X=np.c_[np.ones(m),X]
theta=np.zeros((X.shape[1],1))
ose()
alpha=0.3(2*m)
    thetat)
pH=np.dot(X,theta)
    loss=Y-H
    cost = (np.square(loss)/(2*m))[0,0]
    gradient = (np.dot(loss.T,X))/me()*X1int(hetaT)+int(+(gradient
    
    # loss = Y-H
    # cost = (np.dot(loss.T,loss)/(2*m))[0,0]
ent)/m
    p.asarray(X1),np.asarray(Y))
plt.scatter(np.asarra(X1),np.asarry(H))11
# Out:
# Cost after  1  iteration:  0.004952413764499999
# Cost after  2  iteration:  0.06095782104469968
# Cost after  3  iteration:  0.6878215947516724
# Cost after  4  iteration:  7.80491261845754
# Cost after  5  iteration:  89.38011359786572
# Cost after  6  iteration:  1028.7720645249387
# Cost after  7  iteration:  11869.650627192112
# Cost after  8  iteration:  137096.09765650867
# Cost after  9  iteration:  1584235.6786820793
# Cost after  10  iteration:  18310741.43572326
# Cost after  11  iteration:  211656824.2301675
# Cost after  12  iteration:  2446674993.4294477
# Cost after  13  iteration:  28283167599.1329
# Cost after  14  iteration:  326951411241.8719
# Cost after  15  iteration:  3779548133194.5293
# Cost after  16  iteration:  43691524757252.555
# Cost after  17  iteration:  505073764035642.25
# Cost after  18  iteration:  5838651381959412.0
# Cost after  19  iteration:  6.749480322507562e+16
# Cost after  20  iteration:  7.80239891028242e+17
# ...

# %%
# Out:
#   File "<ipython-input-16-1ad221797bb7>", line 12
#     thetaT=thetaT-alpha*loss.transpose()*(H-Y)/m
#     ^
# IndentationError: unexpected indent

# %%
a=np.array([[1,2],[3,4]])
b=np.array([[5],[6]])
print(np.dot(b,b,a))
# Out:
# [[17]
#  [39]]

# %%
a=np.array([[1],[2]])
b=np.array([[5],[6]])
print(np.dot(a,b))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-fa76e5a569c3> in <module>
#       1 a=np.array([[1],[2]])
#       2 b=np.array([[5],[6]])
# ----> 3 print(np.dot(a,b))
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,1) and (2,1) not aligned: 1 (dim 1) != 2 (dim 0)
