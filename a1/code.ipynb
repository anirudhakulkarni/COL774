# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
X = np.loadtxt("data/q1/linearX.csv", delimiter=",")
Y = np.loadtxt("data/q1/linearY.csv", delimiter=",")
m = len(Y)
print(X)
# Out:
# [ 9.1  8.   9.1  8.4  6.9  7.7 15.6  7.3  7.   7.2 10.1 11.5  7.1 10.
#   8.9  7.9  5.6  6.3  6.7 10.4  8.5  7.4  6.3  5.4  8.9  9.4  7.5 11.9
#   7.8  7.4 10.8 10.2  6.2  7.7 13.7  8.   6.7  6.7  7.   8.3  7.4  9.9
#   6.1  7.   5.4 10.7  7.6  8.9  9.2  6.6  7.2  8.   7.8  7.9  7.   7.
#   7.6  9.1  9.   7.9  6.6 11.9  6.5  7.1  8.8  7.5  7.7  6.  10.6  6.6
#   8.2  7.9  7.1  5.6  6.4  7.5  9.8  7.  10.5  7.1  6.2  6.5  7.7  7.2
#   9.3  8.5  7.7  6.8  7.8  8.7  9.6  7.2  9.3  8.1  6.6  7.8 10.2  6.1
#   7.3  7.3]

# %%
theta=npmasmatrix([0,0])
X1=pd.read_csv("data/q1/linearX.csv",header=None)
Y=pd.read_csv("data/q1/linearY.csv",header=None)
m=len(X)

X1 = np.asmatrix(np.array(X1))
X=np.c_[np.ones(m),X1]
Y = np.asmatrix(np.array(Y))
thetaT=theta.transpose()
alpha=0.3(2*m)
    thetaT=thetaT-alpha*loss.transpose()*(H-Y)/m
    priY-H"Cost after ",i+1," iteration: ",cost)
pr
    gradient=loss.transpose()*X1int(thetaT)
print(+(en(X1)gradient)/m
    p.asarray(X1),np.asarray(Y))
plt.scatter(np.asarray(X1),np.asarray(H))
# Out:
# Cost after  1  iteration:  0.4966279047145
# Cost after  2  iteration:  2471142.977561538
# Cost after  3  iteration:  12843897088181.453
# Cost after  4  iteration:  6.675658702401513e+19
# Cost after  5  iteration:  3.469696064888072e+26
# Cost after  6  iteration:  1.8033862004299565e+33
# Cost after  7  iteration:  9.373160435613272e+39
# Cost after  8  iteration:  4.871731664066172e+46
# Cost after  9  iteration:  2.532098919003734e+53
# Cost after  10  iteration:  1.316066930145436e+60
# Cost after  11  iteration:  6.840302136789776e+66
# Cost after  12  iteration:  3.555270043705155e+73
# Cost after  13  iteration:  1.847863563757627e+80
# Cost after  14  iteration:  9.604333027553884e+86
# Cost after  15  iteration:  4.991884396301747e+93
# Cost after  16  iteration:  2.5945487057301062e+100
# Cost after  17  iteration:  1.3485254168531936e+107
# Cost after  18  iteration:  7.009006213230248e+113
# Cost after  19  iteration:  3.6429545548898104e+120
# ...
