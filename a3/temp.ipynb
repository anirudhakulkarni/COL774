# %%
import matplotlib.pyplot as plt
x=[3, 7, 15, 27, 49, 81, 127, 191, 269, 367, 1375, 3607, 6863, 10047, 12335]
a=[0.8752488387524884, 0.8880778588807786, 0.8880778588807786, 0.8885202388852024, 0.8885202388852024, 0.8889626188896262, 0.8885202388852024, 0.8958195089581951, 0.8953771289537713, 0.8942711789427118, 0.8955983189559832, 0.8958195089581951, 0.8880778588807786, 0.8782488387524884, 0.8752488387524884]
b=[0.8752488387524884, 0.8880778588807786, 0.8880778588807786, 0.8885202388852024, 0.893607608936076, 0.8962618889626189, 0.8953771289537713, 0.8958195089581951, 0.896040698960407, 0.8953771289537713, 0.8940499889404999, 0.8865295288652952, 0.880557398805574, 0.8750276487502765, 0.8723733687237337]
plt.plot(x, a, label='with pruning')
plt.plot(x, b, label='without pruning')
plt.title('Test accuracy vs Number of nodes ')
plt.xlabel('Number of nodes')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('dt_results/dt-qb-prunvsnonprun.png')

# %%
import matplotlib.pyplot as plt
prune_max_list = [100, 200, 300, 400, 500, 600, 700, 800]
prune_train_list=[0.9948296836982968, 0.9890787436407874, 0.9803140898031409, 0.9661302809113028, 0.9591351470913515, 0.9508681707586817, 0.9388133156381332, 0.9255142667551427]
prune_test_list=[0.8644105286441053, 0.8672859986728599, 0.871709798717098, 0.8787878787878788, 0.882769298827693, 0.8867507188675072, 0.8909533289095333, 0.891616898916169]
prune_val_list=[0.8726227333038479, 0.8761609907120743, 0.8825740822644847, 0.8861123396727112, 0.8905351614329943, 0.891640866873065, 0.8929677134011499, 0.897390535161433]    

# prune_train_list=[0.9933919486839194, 0.9795122760451228, 0.9662132271621323, 0.9472185357221854, 0.9310163680601636, 0.9006856890068569]
# prune_test_list=[0.8723733687237337, 0.8779031187790312, 0.880336208803362, 0.8867507188675072, 0.8891838088918381, 0.8845388188453882]
# prune_val_list=[0.8737284387439186, 0.8788146837682441, 0.8841220698805838, 0.8863334807607254, 0.891640866873065, 0.8923042901371074]
plt.figure()
plt.plot(prune_max_list,prune_train_list,
            'r', label='train', marker='o')
plt.plot(prune_max_list, prune_test_list,
            'b', label='test', marker='o')
plt.plot(prune_max_list, prune_val_list,
            'g', label='val', marker='o')
plt.xlabel('Number of subtres pruned')
plt.ylabel('Accuracy')
plt.title('Accuracy vs Number of subtres pruned - Qb - Mult')
plt.legend()
plt.savefig('dt_results/dt-qa-prune-mult.png')

# %%
dictofList={'a':[1,2,3],'b':[4,5,6]}
# for each combination of each element in a and b in dictofList, print a,b
for a,b in dictofList.items():
    print(a,b)
# Out:
# a [1, 2, 3]
# b [4, 5, 6]
